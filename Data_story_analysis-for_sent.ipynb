# %% [markdown]
# **This is the final notebook for Milestone 3, where all the data analysis (besides the pre processing done in Milestone 2) is done.**

# %%
# !pip install --upgrade plotly
# !pip install spacy
# Out:
# Requirement already satisfied: plotly in c:\users\medya\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: six in c:\users\medya\anaconda3\lib\site-packages (from plotly) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\medya\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: spacy in c:\users\medya\anaconda3\lib\site-packages (3.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (8.0.13)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (1.20.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (4.62.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: jinja2 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (2.26.0)
# Requirement already satisfied: setuptools in c:\users\medya\anaconda3\lib\site-packages (from spacy) (58.0.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (0.7.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\medya\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\medya\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\medya\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: colorama in c:\users\medya\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\medya\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\medya\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)

# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import timeit
import bz2
import datetime
import sys
import spacy
#from src.prep_utilities import * 
#from src.prep_pipeline import *

# Load nltk models
#!python ./src/load_models_data.py

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# !python ./src/load_models_data.py
data_folder = './data/'
# Out:
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\medya\anaconda3\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.7)
# Requirement already satisfied: jinja2 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.13)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.6.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.26.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (21.0)
# Requirement already satisfied: setuptools in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (58.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.20.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\medya\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\medya\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\medya\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\medya\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\medya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\medya\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\medya\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\medya\anaconda3\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
spacy.load('en_core_web_sm')

# %% [markdown]
# # General Gender Bias Analyses

# %% [markdown]
# In this section, we plan to analyse:
#  - Evolution of percentage of speakers by gender, over time
#  - Evolution of percentage of quotations by gender, over time
#  - Most quoted speakers by gender, over time

# %% [markdown]
# We'll do a month-by-month analysis. For each month/gender combination, we'll save a Dataframe with the speakers and their total number of quotations that month.

# %%
# Time ranges
years = range(2015,2021)
min_month = "2015-01"
max_month = "2020-04"
all_months = pd.period_range(min_month, max_month, freq='M')

genders = ['male', 'female', 'transgender male', 'transgender female', 'non-binary', 'genderfluid']

# %%
# Create the dictionaries we'll use to store analysis

speaker_df = {} # Save the dataframes of top speakers by gender/month

for gender in genders:  
    speakers_df_temp = {}
    
    for month in all_months:

        speakers_df_temp[month] = pd.DataFrame([], columns = ['speaker', 'numOccurrences']).set_index('speaker')

    speaker_df[gender] = speakers_df_temp
    
speaker_df['male'][all_months[0]]
# Out:
# Empty DataFrame
# Columns: [numOccurrences]
# Index: []

# %% [markdown]
# The pre-processed data will be loaded each year, by chunks. In the analyses, we will cycle through each year, and through each chunk, and save the data.

# %%
# Loop through years
for year in years:
    start = timeit.default_timer()

    # data location and chunk size
    data_file = 'quotes-'+ str(year)+'-prep.json.bz2'
    data_path = data_folder + data_file
    chunk_size = 1e4

    # Load by chunks
    f = bz2.open(data_path, "rb")
    data=pd.read_json(f, lines=True, chunksize=chunk_size)
    
    print(f"Analysing year {year}...", end=" ")
    

    # Loop through chunks
    for i_chunk, chunk in enumerate(data):
        
        ## Run analysis ##
        
        # Create range of months for this year
        if year != 2020:
            months = pd.period_range(str(year)+'-'+'01', str(year)+'-'+'12', freq='M')
        else:
            months = pd.period_range(str(year)+'-'+'01', str(year)+'-'+'04', freq='M')

        # Loop through months
        for month in months:
            # Mask to select desired month
            month_mask = (chunk['date'].dt.to_period('m') == month)
            
            # Loop through genders
            for gender in genders:
                
                # Mask to select desired gender
                gender_mask = (chunk['gender'] == gender)
                
                # Concatenate the speakers in this chunk with our dictionary
                df = chunk[gender_mask & month_mask].groupby("speaker").sum()
                speaker_df[gender][month] = pd.concat([speaker_df[gender][month],df]).groupby("speaker").sum()

    stop = timeit.default_timer()
    print(f"Done in {stop-start:.2f}s")
# Out:
# Analysing year 2015... Done in 1406.01s
# Analysing year 2016... Done in 805.98s
# Analysing year 2017... Done in 1922.07s
# Analysing year 2018...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/75/z_rkqmwd03x6m570l_q8xhyr0000gn/T/ipykernel_16706/181946461.py in <module>
#      16
#      17     # Loop through chunks
# ---> 18     for i_chunk, chunk in enumerate(data):
#      19
#      20         ## Run analysis ##
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in __next__(self)
#     796         if lines:
#     797             lines_json = self._combine_lines(lines)
# --> 798             obj = self._get_object_parser(lines_json)
#     799
#     800             # Make sure that the returned objects have the right index.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# KeyboardInterrupt:

# %%
speaker_df['female'][all_months[12]].sort_values(by='numOccurrences', ascending = False)
#speaker_df['male'][all_months[0]].sum()
# Out:
#                      numOccurrences
# speaker
# Natalie Cole                   1598
# Cheryl Boone Isaacs             418
# Jane Mayer                      272
# Nikki Haley                     151
# Sandra Bland                    145
# ...                             ...
# Julie Goodenough                  1
# Julie Schneider                   1
# Julie Smith                       1
# Julie Snyder                      1
# ronda rousey                      1
#
# [1216 rows x 1 columns]

# %% [markdown]
# Since we don't want to run the previous cell everytime we reload the notebook, we'll save each of the gender/month combinations to a json file.

# %%
general_analysis_folder = data_folder + '/general_analysis/'

for gender in genders:
    for month in all_months:
        if month.year>=2018: ### REMOVE
            with bz2.open(general_analysis_folder + gender +'-' + str(month.year) + '-' + str(month.month) + '.json.bz2', "w") as f:

                # Write to file, reset index to keep the speaker's names
                write = speaker_df[gender][month].reset_index().to_json(f, lines=True, orient='records') 
### 2015,16,17 done

# %% [markdown]
# Now that we've created the files with the analysis data, let's read them again:

# %%
speaker_df = {} # Load the dataframes of top speakers by gender/month
general_analysis_folder = data_folder + '/general_analysis/'

for gender in genders:  
    speakers_df_temp = {}
    
    for month in all_months:
        if month.year <= 2017: ### REMOVE THIS
            speakers_df_temp[month] = pd.read_json(general_analysis_folder + gender +'-' + str(month.year) + '-' + str(month.month) + '.json.bz2', lines = True,compression = 'bz2')

    speaker_df[gender] = speakers_df_temp

# %% [markdown]
# ## Plots
#
# We'll use the `bokeh` package to generate interactive plots.

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from bokeh.models import DatetimeTickFormatter
from bokeh.models import HoverTool, Legend
from bokeh.palettes import brewer


output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="92723">Loading BokehJS ...</span>
#     </div>

# %%
## Prepare data to be plotted ##

# x data
month_str = [str(month.year)+'-'+str(month.month) for month in all_months]
month_dt = [datetime.datetime.strptime(x, '%Y-%m') for x in month_str]

# y data
total_quotations = {} # total quotations by month
for month in all_months[:36]: ### CHANGE THIS
    total_quotations[month] = 0
    for gender in genders:
        total_quotations[month] += speaker_df[gender][month]['numOccurrences'].sum()

perc_quotations = pd.DataFrame([], columns = genders)

for i,month in enumerate(all_months[:36]):
    perc_quotations.loc[i] = [100*speaker_df[gender][month]['numOccurrences'].sum()/total_quotations[month] for gender in genders] ###REMOVE THIS
    
perc_quotations['date'] = month_dt[:36]

# %%
# create a new plot with a title and axis labels
TOOLS = "hover,box_zoom,pan,zoom_in,zoom_out,undo,redo"
colors = brewer['Dark2'][6]

# Figures
p = figure(plot_width = 800, plot_height = 600,tools=TOOLS,title="Percentage of Quotations by Gender", x_axis_label='Time', y_axis_label='Percentage')
p.add_layout(Legend(), 'right')

# Change the mouse hovering over datapoints
hover = p.select(dict(type=HoverTool))

hover.tooltips = [   
    ("Month", "@x{%B %Y}"), # show year month in hover tool
    ("Percentage", "@y{1.1111}"), # this will format as 2-decimal float
]
hover.formatters = {'@x': 'datetime'}


month_dt = month_dt[:36] ###REMOVE THIS
# Line plots
for i,gender in enumerate(genders):
    p.line(perc_quotations['date'], perc_quotations[gender], legend_label=gender, color = colors[i], line_width=2)
#p.multi_line([perc_quotations['date'] for gender in genders], [perc_quotations[gender] for gender in genders], color=brewer['Dark2'][6], line_width = 2, legend_label=genders)


p.xaxis.formatter=DatetimeTickFormatter(
        hours=["%B %Y"],
        days=["%B %Y"],
        months=["%B %Y"],
        years=["%B %Y"],
    )
p.xaxis.major_label_orientation = np.pi/4
p.legend.orientation = "vertical"
p.legend.location = "top"
p.legend.click_policy = 'hide'

# %%
show(p)
# Out:
#   <div class="bk-root" id="4f58c74a-1990-4173-b5f7-9f50892b3724" data-root-id="188333"></div>

# %% [markdown]
# ### Sentiment Analysis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
data_file = 'quotes-2020'+'-prep.json.bz2'
data_path = data_folder + data_file
sent_analysis_folder = data_folder + 'sentiment_analysis/'

# %%
def sent_description(sentiment_score):
    d=''
    if sentiment_score>=0.6:
        d='Strongly positive'
    elif (sentiment_score>=0.4)&(sentiment_score<0.6):
        d='Positive'
    elif (sentiment_score>-0.4)&(sentiment_score<0.4):
        d='Neutral'
    elif (sentiment_score<=-0.4)&(sentiment_score>-0.6):
        d='Negative'
    elif sentiment_score<=-0.6:
        d='Strongly negative'
    return d

# %%
f = bz2.open(data_path, "rb")
data=pd.read_json(f, lines=True, chunksize=10000)

start = timeit.default_timer()
start_progress = timeit.default_timer()
progress_step = 100

with bz2.open(sent_analysis_folder +'2020'+ '.json.bz2', "w") as fn:
    for i_chunk, chunk in enumerate(data):

            # Print progress
            if i_chunk%progress_step == 0:
                stop_progress = timeit.default_timer()
                print(f'Time since last: {stop_progress-start_progress:.1f}s\n')
                print(f"Processing chunks {i_chunk}-{i_chunk+progress_step-1}")
                start_progress = timeit.default_timer()

            # Process chunk
            chunk.drop(columns=['numOccurrences','probas','phase'], inplace=True)
            chunk['sentiment_score']=chunk['quotation'].apply(lambda x: sia.polarity_scores(x)['compound'])
            chunk['sent_description']=chunk['sentiment_score'].apply(lambda x: sent_description(x))
            
            # Write to json.bz2 file
            write = sent.to_json(fn, lines=True, orient='records')

stop = timeit.default_timer()
print(f'Total time: {stop-start:.1f}s\n')
# Out:
# Time since last: 2.5s
#
# Processing chunks 0-99
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2844/1022919177.py in <module>
#      18             # Pre-process chunk
#      19             sent=chunk.copy()
# ---> 20             sent['sentiment_score']=[sia.polarity_scores(i)['compound'] for i in sent['quotation']]
#      21
#      22             # Write to json.bz2 file
#
# ~\AppData\Local\Temp/ipykernel_2844/1022919177.py in <listcomp>(.0)
#      18             # Pre-process chunk
#      19             sent=chunk.copy()
# ---> 20             sent['sentiment_score']=[sia.polarity_scores(i)['compound'] for i in sent['quotation']]
#      21
#      22             # Write to json.bz2 file
#
# ~\anaconda3\lib\site-packages\nltk\sentiment\vader.py in polarity_scores(self, text)
#     359         """
#     360         # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 361         sentitext = SentiText(
#     362             text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     363         )
#
# ~\anaconda3\lib\site-packages\nltk\sentiment\vader.py in __init__(self, text, punc_list, regex_remove_punctuation)
#     272         self.PUNC_LIST = punc_list
#     273         self.REGEX_REMOVE_PUNCTUATION = regex_remove_punctuation
# --> 274         self.words_and_emoticons = self._words_and_emoticons()
#     275         # doesn't separate words from
#     276         # adjacent punctuation (keeps emoticons & contractions)
#
# ~\anaconda3\lib\site-packages\nltk\sentiment\vader.py in _words_and_emoticons(self)
#     304         """
#     305         wes = self.text.split()
# --> 306         words_punc_dict = self._words_plus_punc()
#     307         wes = [we for we in wes if len(we) > 1]
#     308         for i, we in enumerate(wes):
#
# ~\anaconda3\lib\site-packages\nltk\sentiment\vader.py in _words_plus_punc(self)
#     292         # the product gives ('cat', ',') and (',', 'cat')
#     293         punc_before = {"".join(p): p[1] for p in product(self.PUNC_LIST, words_only)}
# --> 294         punc_after = {"".join(p): p[0] for p in product(words_only, self.PUNC_LIST)}
#     295         words_punc_dict = punc_before
#     296         words_punc_dict.update(punc_after)
#
# ~\anaconda3\lib\site-packages\nltk\sentiment\vader.py in <dictcomp>(.0)
#     292         # the product gives ('cat', ',') and (',', 'cat')
#     293         punc_before = {"".join(p): p[1] for p in product(self.PUNC_LIST, words_only)}
# --> 294         punc_after = {"".join(p): p[0] for p in product(words_only, self.PUNC_LIST)}
#     295         words_punc_dict = punc_before
#     296         words_punc_dict.update(punc_after)
#
# KeyboardInterrupt:
